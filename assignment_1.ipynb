# %% [markdown]
# <a href="https://colab.research.google.com/github/baranwal123/my-python-work/blob/main/assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SECTION A

# %% [markdown]
# Q1. Write a program to take your name as input and print a greeting message

# %%
name = input("Enter your name: ")
print("Hello,", name, "! Welcome 😊")
# Out:
# Enter your name: shlok baranwal
# Hello, shlok baranwal ! Welcome 😊

# %% [markdown]
# Q2. Take two numbers as input and print their sum.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print("Sum =", a + b)
# Out:
# Enter first number: 3
# Enter second number: 4
# Sum = 7

# %% [markdown]
# **Q3. Write a program to check the data type of a variable entered by the user.**

# %%
value = input("Enter something: ")
print(type(value))
# Out:
# Enter something: 67
# <class 'str'>

# %% [markdown]
# Q4. Take a string input and print it in uppercase and lowercase

# %%
text = "Shlok"
print(text.upper())
print(text.lower())
# Out:
# SHLOK
# shlok

# %% [markdown]
# Q5. Write a program to count the number of characters in a string

# %%
text = "Shlok"
print(len(text))
# Out:
# 5

# %% [markdown]
# **Q6. Take a string and replace all spaces with underscores (_)**

# %%
text = input("Enter a string: ")
print(text.replace(" ", "_"))
# Out:
# Enter a string: hi i am shlok
# hi_i_am_shlok_

# %% [markdown]
# Q7. Write a program to extract the first and last character of a string.

# %%
text = input("Enter a string: ")
print(text[0])
print(text[-1])
# Out:
# Enter a string: shlok
# s
# k

# %% [markdown]
# Q8. Take user input and print it using formatted string (f-string).

# %%
name = input("Enter your name: ")
print(f"Hello {name}, welcome!")
# Out:
# Enter your name: shlok
# Hello shlok, welcome!

# %% [markdown]
# **Q9. Write a program to concatenate two strings entered by the user.**

# %%
a = input("Enter first string: ")
b = input("Enter second string: ")
print(a + b)
# Out:
# Enter first string: hi
# Enter second string: shlok
# hishlok

# %% [markdown]
# Q10.Take a sentence and remove leading and trailing spaces.

# %%
text = input("Enter a sentence: ")
print(text.strip())
# Out:
# Enter a sentence: hi i am shlok
# hi i am shlok

# %% [markdown]
# SECTION B

# %% [markdown]
# Q11. Banking: Take customer name and account balance, and print a welcome message with balance

# %%
name = input("Enter customer name: ")
balance = float(input("Enter account balance: "))
print(f"Welcome {name}, your account balance is {balance}")
# Out:
# Enter customer name: shlok
# Enter account balance: 7890
# Welcome shlok, your account balance is 7890.0

# %% [markdown]
# Q12. E-commerce: Take product name and price, apply 10% discount and print final price

# %%
product = input("Enter product name: ")
price = float(input("Enter product price: "))

discount = price * 0.10
final_price = price - discount

print("Product:", product)
print("Final Price after 10% discount:", final_price)
# Out:
# Enter product name: pen
# Enter product price: 65
# Product: pen
# Final Price after 10% discount: 58.5

# %% [markdown]
# **Q13. Healthcare: Take patient name and age, print formatted health record message.**

# %%
name = input("Enter patient name: ")
age = int(input("Enter patient age: "))

print(f"Patient Name: {name}")
print(f"Age: {age}")
print("Health record created successfully.")
# Out:
# Enter patient name: shlok
# Enter patient age: 24
# Patient Name: shlok
# Age: 24
# Health record created successfully.

# %% [markdown]
# Q14. Education: Take student name and marks, print a formatted report.

# %%
name = input("Enter student name: ")
marks = float(input("Enter marks: "))

print(f"Student Name: {name}")
print(f"Marks: {marks}")
print("Report generated successfully.")
# Out:
# Enter student name: shlok
# Enter marks: 90
# Student Name: shlok
# Marks: 90.0
# Report generated successfully.

# %% [markdown]
# Q15. Travel: Take city name and print a welcome message in uppercase.

# %%
city = input("Enter city name: ")
print(f"WELCOME TO {city.upper()}")
# Out:
# Enter city name: u.p
# WELCOME TO U.P

# %% [markdown]
# **Q16. HR System: Take employee name and role, print a formatted introduction.**

# %%
name = input("Enter employee name: ")
role = input("Enter employee role: ")

print("Employee Name:", name)
print("Role:", role)
print(f"{name} works as a {role}")
# Out:
# Enter employee name: shlok
# Enter employee role: manager
# Employee Name: shlok
# Role: manager
# shlok works as a manager

# %% [markdown]
# Q17. Food Delivery: Take food item and quantity, print order summary.

# %%
item = input("Enter food item: ")
quantity = int(input("Enter quantity: "))

print("Order Summary")
print("Item:", item)
print("Quantity:", quantity)
# Out:
# Enter food item: rice
# Enter quantity: 2
# Order Summary
# Item: rice
# Quantity: 2

# %% [markdown]
# Q18. Login System: Take username and remove extra spaces using strip().

# %%
username = "Shlok   "
clean_username = username.strip()

print("output is:", clean_username)
# Out:
# output is: Shlok

# %% [markdown]
# Q19. Data Cleaning: Take a string and replace special characters (#, @) with empty string

# %%
text = "Sh#lo@k is #good@"

text = text.replace("#", "")
text = text.replace("@", "")

print(text)
# Out:
# Shlok is good

# %% [markdown]
# Q20. Chat Application: Take user message and print it in title case.

# %%
message = input("Enter your message: ")
print(message.title())
# Out:
# Enter your message: hi i am ggod
# Hi I Am Ggod
